# %%
import pickle
import numpy as np
import json

# %%
c = {'q':[], 'qdot':[], 'qddot':[]}
c['q'].append(np.array([1,2,3,4]))
c['qdot'].append(np.array([11,12,13,14]))
c['qddot'].append(np.array([111,122,133,144]))

# %%
with open("mpc_var", "wb") as fp:
    pickle.dump(c, fp)

# %%
with open("mpc_var", "rb") as fp:
    z = pickle.load(fp)

# %%
z
# Out:
# {'q': [array([1, 2, 3, 4])],
#  'qdot': [array([11, 12, 13, 14])],
#  'qddot': [array([111, 122, 133, 144])]}
